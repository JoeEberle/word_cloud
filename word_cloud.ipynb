# %% [markdown]
# ![word_cloud.png](attachment:word_cloud.png)

# %% [markdown]
# ## Word Cloud
# ##### Created Joe Eberle - 11/23/2022
#
# 1. Import Libraries - Import necessary libraries such as matplotlib.pyplot and WordCloud.
# 2. Prepare Text Data - Have your text data ready, which could be a string or a collection of text.
# 3. Generate Word Cloud - Create a WordCloud object and generate the word cloud from your text data.
# 4. Display Word Cloud - Use matplotlib.pyplot to display the generated word cloud.

# %% [markdown]
# ![joe_logo.png](attachment:joe_logo.png)git push -u origin main

# %%
import pandas as pd #Pandas is high performance data manipulation 
import matplotlib.pyplot as plt   # matplot is for python graphics
import numpy as np   #numpy is for array processing
import seaborn  as sns
import plotly.express as px
import PIL.Image
from wordcloud import WordCloud, STOPWORDS
stopwords = STOPWORDS

# %%
shape = np.array(PIL.Image.open('heart.png'))

# %% [markdown]
# ## Optional Step 0 - Intitiate Configuration Settings and name the overall solution

# %%
# Install any libraries you dont already have installed 
import configparser   
from datetime import date, datetime

# establish the configuration settings parser
config = configparser.ConfigParser()  
cfg = config.read('config.ini')   

# Establish some parameters 
solution_name = 'word_cloud'

# %% [markdown]
# ## Optional Step 0 - Intitiate the Logger

# %%
# Establish the Python Logger  
import logging # built in python library that does not need to be installed 
import quick_logger as ql

global start_stime 
start_time = ql.set_start_time()
logging = ql.create_logger_Start(solution_name, start_time)

# %%
Introduction =  "A word cloud is a visual representation of text data where the size of each word corresponds to its frequency or importance within a given text corpus. "
Introduction = Introduction + "It helps to highlight the most prominent and recurring terms in a textual data set providing a quick overview of the most common words.  "
Introduction = Introduction + "In data science, word clouds aid in text analysis, sentiment analysis, and summarizing textual content, allowing data scientists to quickly identify key themes and trends within large volumes of text data.  "

credits = "This code was developed by Joe Eberle and Others"

talking_introduction  = False
if talking_introduction:
    ql.talk(Introduction)
else:
    print(Introduction)

# %%
provide_documentation = True
if provide_documentation:  
        ql.pvlog('info',f'Process {solution_name} Step 2 - Read the Solution documentation.')     
        ql.talk(Introduction)
        ql.talk(credits)
        process_steps = "The 4 simple steps for this process are:"
        process_steps = process_steps + "Step 1 - Import Libraries - Import necessary libraries such as matplotlib.pyplot and WordCloud."
        process_steps = process_steps + "Step 2 - Prepare Text Data - Have your text data ready, which could be a string or a collection of text."
        process_steps = process_steps + "Step 3 - Generate Word Cloud - Create a WordCloud object and generate the word cloud from your text data."
        process_steps = process_steps + "Step 4 - Display Word Cloud - Use matplotlib.pyplot to display the generated word cloud."
        process_steps = process_steps + "Step 5 - Observe- Observe the word cloud to gain insights of the corpuses meaning ."
 

        ql.talk(process_steps)  
        terms = 'The terminology for this project is:'
        terms = terms + 'The word cloud library is a great library for Natural Language Processing (NLP) and building word Clouds. '
        ql.talk(terms)
# Out:
# Process word_cloud Step 2 - Read the Solution documentation.

# %%
text3 = 'Python pandas is a popular library for Artificial Intelligence (AI) and data science tasks' 
text3 = text3 + 'due to its efficient handling of large datasets and powerful data manipulation and analysis tools.'
text3 = text3 + 'It provides an easy-to-use interface for reading data from various sources, cleaning and preparing data '
text3 = text3 +  'for analysis, and performing statistical analysis and machine learning tasks. Overall, '
text3 = text3 +  'pandas is an essential tool for anyone working in AI and data science, enabling them to '
text3 = text3 +  'efficiently and effectively process, manipulate, and analyze data to generate insights and'
text3 = text3 +  'build predictive models.'

# %%
text4 = 'Trees are an essential part of human life, providing us with oxygen, food, shelter, and numerous resources.'
text4 = text4 +  'Without trees, the balance of our ecosystem and the survival of our planet would be severely compromised.'

# %%
debugging_and_testing = False
if debugging_and_testing:
    print(stopwords)

# %%
text2 = 'Python pandas is a versatile library that is widely used in Natural Language Processing (NLP) tasks. NLP involves the analysis and processing of human language, and pandas provides a powerful toolset for managing textual data. Pandas DataFrame object can be used to store and manipulate text data, allowing for efficient processing of large datasets. It also provides functions for cleaning and preprocessing text data, such as removing stop words, stemming, and lemmatization. Additionally, pandas can be used in conjunction with other NLP libraries, such as NLTK and spaCy, to perform more advanced NLP tasks like sentiment analysis and named entity recognition. Overall, pandas is a valuable tool for anyone working in NLP, providing an intuitive interface for managing and processing textual data.'

# %%
print(text2)
# Out:
# Python pandas is a versatile library that is widely used in Natural Language Processing (NLP) tasks. NLP involves the analysis and processing of human language, and pandas provides a powerful toolset for managing textual data. Pandas DataFrame object can be used to store and manipulate text data, allowing for efficient processing of large datasets. It also provides functions for cleaning and preprocessing text data, such as removing stop words, stemming, and lemmatization. Additionally, pandas can be used in conjunction with other NLP libraries, such as NLTK and spaCy, to perform more advanced NLP tasks like sentiment analysis and named entity recognition. Overall, pandas is a valuable tool for anyone working in NLP, providing an intuitive interface for managing and processing textual data.

# %%
text1 = 'Cats are Fun. Fava bean is the name of Ella"s Cat'
text1 = text1 + 'Fava bean is still a kitty. He is very Curiuos, Fava sometimes pounces.'
text1 = text1 + 'Fava likes to meow. Fava is a good cat sometimes'
text1 = text1 + 'Fava likes to jump and play. Fava is a cat not a bean'
text1 = text1 + 'Fava is orange and white'

print(text2)
# Out:
# Python pandas is a versatile library that is widely used in Natural Language Processing (NLP) tasks. NLP involves the analysis and processing of human language, and pandas provides a powerful toolset for managing textual data. Pandas DataFrame object can be used to store and manipulate text data, allowing for efficient processing of large datasets. It also provides functions for cleaning and preprocessing text data, such as removing stop words, stemming, and lemmatization. Additionally, pandas can be used in conjunction with other NLP libraries, such as NLTK and spaCy, to perform more advanced NLP tasks like sentiment analysis and named entity recognition. Overall, pandas is a valuable tool for anyone working in NLP, providing an intuitive interface for managing and processing textual data.

# %%
shape = np.array(PIL.Image.open('cat3.jpg'))

wc = WordCloud(
        background_color ='white',
        stopwords=stopwords,
        mask = shape,
        height=600,
        width=400,
        contour_color='blue',
        contour_width=5
)

wc.generate(text1)
plt.imshow(wc)

# %%
shape = np.array(PIL.Image.open('tree.jpg'))

wc = WordCloud(
        background_color ='white',
        stopwords=stopwords,
        mask = shape,
        height=600,
        width=400,
        contour_color='green',
        contour_width=10
)

wc.generate(text4)
plt.imshow(wc)

# %%
t4 = ' Anna Mucha'
t4 = t4 + ' Application Software – Microsoft Office including, Word, Excel, PowerPoint, OneNote, Outlook, Visio, Access, Visual Studio, and Oracle APEX'
t4 = t4 + ' Languages – Visual Basic, SQL, CSS/HTML, Python, Tableau and C++'
t4 = t4 + ' Anna Mucha'
t4 = t4 + ' Kaleida Health – Buffalo, N.Y' 
t4 = t4 + ' Automate excel documents' 
t4 = t4 + ' Mucha'
t4 = t4 + ' Mucha'
t4 = t4 + ' Mucha'
t4 = t4 + ' Mucha'
t4 = t4 + ' Anna'
t4 = t4 + ' Anna'
t4 = t4 + ' Anna'
t4 = t4 + ' Anna'
t4 = t4 + ' Producing visual dashboards for health care data'  
t4 = t4 + ' Anna Mucha'
t4 = t4 + ' Buffalo State College – Buffalo, N.Y.'
t4 = t4 + ' Dean’s List'
t4 = t4 + ' Dean’s List Summa Cum Laude'
t4 = t4 + ' Summa Cum Laude'
t4 = t4 + ' Summa Cum Laude'

# %%
shape = np.array(PIL.Image.open('bunny.jpg'))

wc = WordCloud(
        background_color ='white',
        stopwords=stopwords,
        mask = shape,
        height=800,
        width=600,
        contour_color='green',
        contour_width=10
)

wc.generate(t4)
plt.imshow(wc)

# %%
wc.to_file('wordcloud_output.png')

# %%
t4 = ' Frank Metty'
t4 = t4 + ' Bridge transfusion integration into Cerner EMR Studio, and Oracle APEX'
t4 = t4 + ' Project Management'
t4 = t4 + ' Frank Metty'
t4 = t4 + ' Kaleida Health – Buffalo, N.Y' 
t4 = t4 + ' Professional Experience' 
t4 = t4 + ' Frank Metty'
t4 = t4 + ' Metty'
t4 = t4 + ' Frank'
t4 = t4 + ' Metty'
t4 = t4 + ' Configuration, maintenance and implementation of EMR applications'
t4 = t4 + ' Frank Metty'
t4 = t4 + ' Frank Metty'
t4 = t4 + ' Corepoint HL7 Integration Level I '
t4 = t4 + ' IT Analyst'  
t4 = t4 + ' EMR Integration'
t4 = t4 + ' Buffalo State College – Buffalo, N.Y.'

# %%
shape = np.array(PIL.Image.open('baguette.jpg'))

wc = WordCloud(
        background_color ='white',
        stopwords=stopwords,
        mask = shape,
        height=800,
        width=600,
        contour_color='green',
        contour_width=10
)

wc.generate(t4)
plt.imshow(wc)

# %%
shape = np.array(PIL.Image.open('brain.jpg'))

wc = WordCloud(
        background_color ='white',
        stopwords=stopwords,
        mask = shape,
        height=600,
        width=400,
        contour_color='green',
        contour_width=10
)

wc.generate(text3)
plt.imshow(wc)

# %%
wc.generate(text2)
wc.to_file('wordcloud_output.png')
plt.figure(figsize = (5,20))
plt.imshow(wc)

# %% [markdown]
# ## Step 1 -Format Entire Directory of Excel Files

# %%
# optional education - The following code will only run if educating is set to True for this solution
if config.get('global_infrastructure', 'documenting') == 'True':
    import os 
    import solution_documentation_rpa_excel as sd    # Establish the solutions documentation as sd 
    solution_documentation = sd.get_solution_documentation()  
    print(solution_documentation) 
    solution_document_file_name =  config.get('global_infrastructure', 'infrastructure_directory') + '/' + config.get('global_infrastructure', 'documentation_directory')+ '/documentation_' + solution_name + config.get('global_infrastructure', 'documentation_extension')
    sd.save_documentation(solution_document_file_name) 
    print('Solution Documention saved to file: {} '.format(solution_document_file_name))   
    
    
if config.get(solution_name, 'talking_code') == 'True': 
    import talking_code as tc  
    tc.say(solution_documentation)
# Out:
# This data science solution will enhance and improve your excel files automatically.
# This helps give all your excel files the same look and feel.
# You can easily modify the look and feel of your excel reports to make them your own.
# This solution will help you document by adding meta tags to your existing excel.
# This solution will help eliminate hours of manual formatting.
#
#
#
# This data science solution was developed in collaboration with Joe Eberle.
# The solution was developed in Python starting on 11/13/2022
# This solution is free and open source and the code is openly available for general use.
# The steps for this solution are:
# Step 1: identify the directory to format excel files.
# Step 2: run the remote process to format the excel files .
# Step 3: optional test - Visually inspect a sample of  your modified excel files.
#
#
# The additional notes for this solution are:
# Note 1: This solution makes and saves a formatted copy of your excel files.
# ...

# %%
# Calculate and classify the process performance 
status = ql.calculate_process_performance(solution_name, start_time) 
print(ql.append_log_file(solution_name))

# %% [markdown]
# ![joe_logo.png](attachment:joe_logo.png)git push -u origin main
