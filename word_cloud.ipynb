# %% [markdown]
# ![word_cloud.png](attachment:word_cloud.png)

# %% [markdown]
# ## Word Cloud
# ##### Created Joe Eberle - 11/23/2022
#
# **Word Cloud** A word cloud visually represents text data, with each word's size reflecting its frequency or importance in the corpus. It illuminates prominent and recurring terms, offering a snapshot of common words in a dataset. Word clouds assist in text analysis, sentiment analysis, and summarization, enabling data scientists to discern key themes and trends in large volumes of text data efficiently.
#
# **Word clouds** are commonly used by analysts, researchers, and marketers to quickly visualize and identify prevalent themes or keywords within large textual datasets, aiding in data interpretation and decision-making processes. They offer a concise and visually engaging summary of text content, making it easier for users to grasp the most significant aspects of the data at a glancuses meaning . d.

# %% [markdown]
# The steps are:
# 1.  Import Libraries - Import necessary libraries such as matplotlib.pyplot and WordCloud.
# 2.  Prepare Text Data - Have your text data ready, which could be a string or a collection of text.
# 3. Generate Word Cloud - Create a WordCloud object and generate the word cloud from your text data.
# 4. Display Word Cloud - Use matplotlib.pyplot to display the generated word cloud.
# 5. Observe- Observe the word cloud to gain insights of the corpuses meaning.

# %%
import pandas as pd #Pandas is high performance data manipulation 
import matplotlib.pyplot as plt   # matplot is for python graphics
import numpy as np   #numpy is for array processing
import seaborn  as sns
import plotly.express as px
import PIL.Image
from wordcloud import WordCloud, STOPWORDS
stopwords = STOPWORDS

# %%
shape = np.array(PIL.Image.open('heart.png'))

# %% [markdown]
# ## Optional Step 0 - Intitiate Configuration Settings and name the overall solution

# %%
# Install any libraries you dont already have installed 
import configparser   
from datetime import date, datetime

# establish the configuration settings parser
config = configparser.ConfigParser()  
cfg = config.read('config.ini')   

# Establish some parameters 
solution_name = 'word_cloud'

# %% [markdown]
# ## Optional Step 0 - Intitiate the Logger

# %%
# Establish the Python Logger  
import logging # built in python library that does not need to be installed 
import quick_logger as ql

global start_stime 
start_time = ql.set_start_time()
logging = ql.create_logger_Start(solution_name, start_time)

# %%
definition = '''
**Word Cloud** A word cloud visually represents text data, with each word's size reflecting its frequency or importance in the corpus. It illuminates prominent and recurring terms, offering a snapshot of common words in a dataset. Word clouds assist in text analysis, sentiment analysis, and summarization, enabling data scientists to discern key themes and trends in large volumes of text data efficiently. 

**Word clouds** are commonly used by analysts, researchers, and marketers to quickly visualize and identify prevalent themes or keywords within large textual datasets, aiding in data interpretation and decision-making processes. They offer a concise and visually engaging summary of text content, making it easier for users to grasp the most significant aspects of the data at a glance.

''' 
# Write the solution defitions out to the solution_description.md file
file_name = "solution_description.md"
with open(file_name, 'w') as f:
    # Write the template to the readme.md file
     f.write(definition)

talking_code = False
if talking_code:
    tc.print_say(definition) 
else:
    print(definition)
# Out:
# **Word Cloud** A word cloud visually represents text data, with each word's size reflecting its frequency or importance in the corpus. It illuminates prominent and recurring terms, offering a snapshot of common words in a dataset. Word clouds assist in text analysis, sentiment analysis, and summarization, enabling data scientists to discern key themes and trends in large volumes of text data efficiently.
#
# **Word clouds** are commonly used by analysts, researchers, and marketers to quickly visualize and identify prevalent themes or keywords within large textual datasets, aiding in data interpretation and decision-making processes. They offer a concise and visually engaging summary of text content, making it easier for users to grasp the most significant aspects of the data at a glance.

# %%
provide_documentation = True
if provide_documentation:  
        process_steps = "The steps for this process are:\n"
        process_steps += "Step 1 - Import Libraries - Import necessary libraries such as matplotlib.pyplot and WordCloud. \n"
        process_steps += "Step 2 - Prepare Text Data - Have your text data ready, which could be a string or a collection of text. \n"
        process_steps += "Step 3 - Generate Word Cloud - Create a WordCloud object and generate the word cloud from your text data. \n"
        process_steps += "Step 4 - Display Word Cloud - Use matplotlib.pyplot to display the generated word cloud. \n"
        process_steps += "Step 5 - Observe- Observe the word cloud to gain insights of the corpuses meaning . \n"
print(process_steps)
# Out:
# The steps for this process are:
# Step 1 - Import Libraries - Import necessary libraries such as matplotlib.pyplot and WordCloud.
# Step 2 - Prepare Text Data - Have your text data ready, which could be a string or a collection of text.
# Step 3 - Generate Word Cloud - Create a WordCloud object and generate the word cloud from your text data.
# Step 4 - Display Word Cloud - Use matplotlib.pyplot to display the generated word cloud.
# Step 5 - Observe- Observe the word cloud to gain insights of the corpuses meaning .

# %%
text4 = 'Trees are an essential part of human life, providing us with oxygen, food, shelter, and numerous resources.'
text4 = text4 +  'Without trees, the balance of our ecosystem and the survival of our planet would be severely compromised.'

# %%
debugging_and_testing = False
if debugging_and_testing:
    print(stopwords)

# %%
text2 = 'Python pandas is a versatile library that is widely used in Natural Language Processing (NLP) tasks. NLP involves the analysis and processing of human language, and pandas provides a powerful toolset for managing textual data. Pandas DataFrame object can be used to store and manipulate text data, allowing for efficient processing of large datasets. It also provides functions for cleaning and preprocessing text data, such as removing stop words, stemming, and lemmatization. Additionally, pandas can be used in conjunction with other NLP libraries, such as NLTK and spaCy, to perform more advanced NLP tasks like sentiment analysis and named entity recognition. Overall, pandas is a valuable tool for anyone working in NLP, providing an intuitive interface for managing and processing textual data.'

# %%
print(text2)
# Out:
# Python pandas is a versatile library that is widely used in Natural Language Processing (NLP) tasks. NLP involves the analysis and processing of human language, and pandas provides a powerful toolset for managing textual data. Pandas DataFrame object can be used to store and manipulate text data, allowing for efficient processing of large datasets. It also provides functions for cleaning and preprocessing text data, such as removing stop words, stemming, and lemmatization. Additionally, pandas can be used in conjunction with other NLP libraries, such as NLTK and spaCy, to perform more advanced NLP tasks like sentiment analysis and named entity recognition. Overall, pandas is a valuable tool for anyone working in NLP, providing an intuitive interface for managing and processing textual data.

# %%
text1 = """
Cats are Fun. Fava bean is the name of Ella"s Cat.
Fava bean is still a kitty. He is very Curiuos, Fava sometimes pounces. 
Fava likes to meow. Fava is a good cat sometimes 
Fava likes to jump and play. Fava is a cat not a bean 
Fava is orange and white'
"""

print(text1)
# Out:
# Cats are Fun. Fava bean is the name of Ella"s Cat.
# Fava bean is still a kitty. He is very Curiuos, Fava sometimes pounces.
# Fava likes to meow. Fava is a good cat sometimes
# Fava likes to jump and play. Fava is a cat not a bean
# Fava is orange and white'

# %%
shape = np.array(PIL.Image.open('cat3.jpg'))

wc = WordCloud(
        background_color ='white',
        stopwords=stopwords,
        mask = shape,
        height=600,
        width=400,
        contour_color='blue',
        contour_width=5
)

wc.generate(text1)
plt.imshow(wc)

# %%
shape = np.array(PIL.Image.open('tree.jpg'))

wc = WordCloud(
        background_color ='white',
        stopwords=stopwords,
        mask = shape,
        height=600,
        width=400,
        contour_color='green',
        contour_width=10
)

wc.generate(text4)
plt.imshow(wc)

# %%
t4 = """
Immunotherapy
A type of cancer treatment designed to boost the body's natural defenses to fight the cancer. It uses materials made either by the body or in a laboratory to improve, target, or restore immune system function. It may also be called biologic therapy. Learn more about immunotherapy.
"""

# %%
shape = np.array(PIL.Image.open('brain.jpg'))

wc = WordCloud(
        background_color ='white',
        stopwords=stopwords,
        mask = shape,
        height=800,
        width=600,
        contour_color='PINK',
        contour_width=10
)

wc.generate(t4)
plt.imshow(wc)

# %%
wc.to_file('wordcloud_output.png')

# %%
shape = np.array(PIL.Image.open('brain.jpg'))

wc = WordCloud(
        background_color ='white',
        stopwords=stopwords,
        mask = shape,
        height=600,
        width=400,
        contour_color='green',
        contour_width=10
)

wc.generate(text2)
plt.imshow(wc)

# %%
wc.generate(text4)
wc.to_file('wordcloud_output.png')
plt.figure(figsize = (5,20))
plt.imshow(wc)

# %% [markdown]
# ## Step 1 -Format Entire Directory of Excel Files

# %%
# optional education - The following code will only run if educating is set to True for this solution
if config.get('global_infrastructure', 'documenting') == 'True':
    import os 
    import solution_documentation_rpa_excel as sd    # Establish the solutions documentation as sd 
    solution_documentation = sd.get_solution_documentation()  
    print(solution_documentation) 
    solution_document_file_name =  config.get('global_infrastructure', 'infrastructure_directory') + '/' + config.get('global_infrastructure', 'documentation_directory')+ '/documentation_' + solution_name + config.get('global_infrastructure', 'documentation_extension')
    sd.save_documentation(solution_document_file_name) 
    print('Solution Documention saved to file: {} '.format(solution_document_file_name))   
    
    
if config.get(solution_name, 'talking_code') == 'True': 
    import talking_code as tc  
    tc.say(solution_documentation)
# Out:
# ---------------------------------------------------------------------------
# NoSectionError                            Traceback (most recent call last)
# Cell In[19], line 2
#       1 # optional education - The following code will only run if educating is set to True for this solution
# ----> 2 if config.get('global_infrastructure', 'documenting') == 'True':
#       3     import os
#       4     import solution_documentation_rpa_excel as sd    # Establish the solutions documentation as sd
#
# File ~\anaconda3\lib\configparser.py:781, in RawConfigParser.get(self, section, option, raw, vars, fallback)
#     766 """Get an option value for a given section.
#     767
#     768 If `vars' is provided, it must be a dictionary. The option is looked up
#    (...)
#     778 The section DEFAULT is special.
#     779 """
#     780 try:
# --> 781     d = self._unify_values(section, vars)
#     782 except NoSectionError:
#     783     if fallback is _UNSET:
#
# ...

# %%
# Calculate and classify the process performance 
status = ql.calculate_process_performance(solution_name, start_time) 
print(ql.append_log_file(solution_name))

# %% [markdown]
# ![joe_logo.png](attachment:joe_logo.png)git push -u origin main
